# %%
# Import dependencies
from pathlib import Path
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read in CSV
datafile = Path("worldometer_coronavirus_daily_data.csv")
daily_covid_df = pd.read_csv(datafile)
daily_covid_df.head()
# Out:
#         date      country  cumulative_total_cases  daily_new_cases  \
# 0  2020-2-15  Afghanistan                     0.0              NaN
# 1  2020-2-16  Afghanistan                     0.0              NaN
# 2  2020-2-17  Afghanistan                     0.0              NaN
# 3  2020-2-18  Afghanistan                     0.0              NaN
# 4  2020-2-19  Afghanistan                     0.0              NaN
#
#    active_cases  cumulative_total_deaths  daily_new_deaths
# 0           0.0                      0.0               NaN
# 1           0.0                      0.0               NaN
# 2           0.0                      0.0               NaN
# 3           0.0                      0.0               NaN
# 4           0.0                      0.0               NaN

# %%
# Convert date coulumn to datetime and create a 'year_month' column
daily_covid_df['date'] = pd.to_datetime(daily_covid_df['date'])
daily_covid_df['year_month'] = daily_covid_df['date'].dt.strftime('%Y-%m')
daily_covid_df.head()
# Out:
#         date      country  cumulative_total_cases  daily_new_cases  \
# 0 2020-02-15  Afghanistan                     0.0              NaN
# 1 2020-02-16  Afghanistan                     0.0              NaN
# 2 2020-02-17  Afghanistan                     0.0              NaN
# 3 2020-02-18  Afghanistan                     0.0              NaN
# 4 2020-02-19  Afghanistan                     0.0              NaN
#
#    active_cases  cumulative_total_deaths  daily_new_deaths year_month
# 0           0.0                      0.0               NaN    2020-02
# 1           0.0                      0.0               NaN    2020-02
# 2           0.0                      0.0               NaN    2020-02
# 3           0.0                      0.0               NaN    2020-02
# 4           0.0                      0.0               NaN    2020-02

# %%
# Groupby 'year_month' and 'daily_new_cases' to plot the average new cases over time
avg_new_cases_df = daily_covid_df.groupby('date')['daily_new_cases'].mean().reset_index()
plt.figure(figsize=(10, 6))
plt.plot(avg_new_cases_df['date'], avg_new_cases_df['daily_new_cases'], marker='o', linestyle='-')
plt.title('Global COVID Cases')
plt.ylabel('Average Daily New Cases')
plt.xticks(rotation=45)  
plt.show()

# %%
# Groupby 'year_month' and 'active_cases' to plot the average active cases over time
avg_active_cases_df = daily_covid_df.groupby('date')['active_cases'].mean().reset_index()
plt.figure(figsize=(10, 6))
plt.plot(avg_active_cases_df['date'], avg_active_cases_df['active_cases'], marker='o', linestyle='-')
plt.title('Global COVID Cases')
plt.ylabel('Average Active Cases')
plt.xticks(rotation=45)  
plt.show()

# %%
# Groupby 'year_month' and 'daily_new_deaths' to plot the average daily deaths over time
avg_deaths_df = daily_covid_df.groupby('date')['daily_new_deaths'].mean().reset_index()
plt.figure(figsize=(10, 6))
plt.plot(avg_deaths_df['date'], avg_deaths_df['daily_new_deaths'], marker='o', linestyle='-')
plt.title('Global COVID Deaths')
plt.ylabel('Average Daily Deaths')
plt.xticks(rotation=45)  
plt.show()

# %%
# Merge the average new cases, active case and deaths dataframes
day_pivot_df = pd.merge(pd.merge(avg_new_cases_df, avg_active_cases_df, on=['date']), avg_deaths_df, on='date')
day_pivot_df.set_index('date', inplace=True)
# day_pivot_df.head()

# %%
# Plot each column of day_pivot_df on individual graphs
plt.figure(figsize=(10, 10))
for i, column in enumerate(day_pivot_df.columns):
    ax = plt.subplot(len(day_pivot_df.columns), 1, i + 1)
    ax.plot(day_pivot_df.index, day_pivot_df[column], marker='o', linestyle='-', label=column)
    ax.set_title(column)
    ax.set_ylabel('Total Daily')

plt.tight_layout()
plt.show()

# %%
# Normalize the data in each column
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(day_pivot_df)
daily_normalized_df = pd.DataFrame(scaled_data, columns=day_pivot_df.columns, index=day_pivot_df.index)

# Plot the normalized data
plt.figure(figsize=(15, 10))
for column in daily_normalized_df.columns:
    plt.plot(daily_normalized_df.index, daily_normalized_df[column], marker='o', linestyle='-', label=column)

plt.title('Global COVID (Normalized)')
plt.ylabel('Total Daily (Normalized)')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
# Monthly COVID

# %%
# Convert the daily data to Monthly and create new dataframe
# Sum the 'daily_new_cases' of each month for each country to get 'monthly_new_cases'
monthly_new_cases = daily_covid_df.groupby(['country', 'year_month'])['daily_new_cases'].sum().reset_index()
monthly_new_cases = monthly_new_cases.rename(columns={'daily_new_cases': 'monthly_new_cases'})

# Sum the 'daily_new_deaths' of each month for each country to 'get monthly_new_deaths'
monthly_new_deaths = daily_covid_df.groupby(['country', 'year_month'])['daily_new_deaths'].sum().reset_index()
monthly_new_deaths = monthly_new_deaths.rename(columns={'daily_new_deaths': 'monthly_new_deaths'})

# Group by 'year_month' then filter to select the last day of each month
last_day_of_month = daily_covid_df.groupby(['year_month']).apply(lambda x: x[x['date'] == x['date'].max()])

# Reset index to remove multi-index resulting from groupby
last_day_of_month.reset_index(drop=True, inplace=True)

# Remove the daily columns from 'last_day_of_month'
last_day_of_month = last_day_of_month.drop(columns=['daily_new_cases', 'daily_new_deaths'])

# Merge the monthly sums data into 'last_day_of_month' to create 'monthly_covid_df'
monthly_covid_df = pd.merge(last_day_of_month, monthly_new_cases, on=['country', 'year_month'], how='left')
monthly_covid_df = pd.merge(monthly_covid_df, monthly_new_deaths, on=['country', 'year_month'], how='left')

# Reorganize the column order
monthly_covid_df = monthly_covid_df[['year_month', 'country', 'cumulative_total_cases', 'monthly_new_cases', 
                                    'active_cases', 'cumulative_total_deaths', 'monthly_new_deaths']]

# Print the resulting DataFrame
monthly_covid_df.head()
# Out:
#   year_month      country  cumulative_total_cases  monthly_new_cases  \
# 0    2020-01        China                 11791.0            11220.0
# 1    2020-02  Afghanistan                     1.0                0.0
# 2    2020-02      Albania                     0.0                0.0
# 3    2020-02      Algeria                     1.0                0.0
# 4    2020-02      Andorra                     0.0                0.0
#
#    active_cases  cumulative_total_deaths  monthly_new_deaths
# 0       11289.0                    259.0               242.0
# 1           1.0                      0.0                 0.0
# 2           0.0                      0.0                 0.0
# 3           1.0                      0.0                 0.0
# 4           0.0                      0.0                 0.0

# %%
# Export the Education dataframe into a csv
# last_day_of_month.to_csv("output_data/monthly_covid_data.csv")

# %%
# Groupby 'year_month' and 'daily_new_cases' to plot the average new cases over time
total_new_cases_df = monthly_covid_df.groupby('year_month')['monthly_new_cases'].sum().reset_index()
plt.figure(figsize=(10, 6))
plt.plot(total_new_cases_df['year_month'], total_new_cases_df['monthly_new_cases'], marker='o', linestyle='-')
plt.title('Global COVID Cases')
plt.ylabel('Total Monthly New Cases')
plt.xticks(rotation=45)  
plt.show()

# %%
# Groupby 'year_month' and 'active_cases' to plot the average active cases over time
active_cases_df = monthly_covid_df.groupby('year_month')['active_cases'].sum().reset_index()
plt.figure(figsize=(10, 6))
plt.plot(active_cases_df['year_month'], active_cases_df['active_cases'], marker='o', linestyle='-')
plt.title('Global COVID Cases')
plt.ylabel('Total Active Cases')
plt.xticks(rotation=45)  
plt.show()

# %%
total_deaths_df = monthly_covid_df.groupby('year_month')['monthly_new_deaths'].sum().reset_index()
plt.figure(figsize=(10, 6))
plt.plot(total_deaths_df['year_month'], total_deaths_df['monthly_new_deaths'], marker='o', linestyle='-')
plt.title('Global COVID Deaths')
plt.ylabel('Total Monthly Deaths')
plt.xticks(rotation=45)  
plt.show()

# %%
# Merge the average new cases, active case and deaths dataframes
month_pivot_df = pd.merge(pd.merge(total_new_cases_df, active_cases_df, on=['year_month']), total_deaths_df, on='year_month')
month_pivot_df.set_index('year_month', inplace=True)
# month_pivot_df.head()

# %%
# Plot each column of month_pivot_df on individual graphs
plt.figure(figsize=(10, 10))
for i, column in enumerate(month_pivot_df.columns):
    ax = plt.subplot(len(month_pivot_df.columns), 1, i + 1)
    ax.plot(month_pivot_df.index, month_pivot_df[column], marker='o', linestyle='-', label=column)
    ax.set_title(column)
    ax.set_ylabel('Total Monthly')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 8))

for column in month_pivot_df.columns:
    plt.plot(month_pivot_df.index, month_pivot_df[column], marker='o', linestyle='-', label=column)


plt.title('Total Global COVID')
plt.ylabel('Monthly Total')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Normalize the data in each column
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(month_pivot_df)
monthly_normalized_df = pd.DataFrame(scaled_data, columns=month_pivot_df.columns, index=month_pivot_df.index)

# Plot the normalized data
plt.figure(figsize=(15, 8))
for column in monthly_normalized_df.columns:
    plt.plot(monthly_normalized_df.index, monthly_normalized_df[column], marker='o', linestyle='-', label=column)

plt.title('Global COVID (Normalized)')
plt.ylabel('Total Monthly (Normalized)')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
# Top COVID Countries

# %%
daily_covid_df.head()
# Out:
#         date      country  cumulative_total_cases  daily_new_cases  \
# 0 2020-02-15  Afghanistan                     0.0              NaN
# 1 2020-02-16  Afghanistan                     0.0              NaN
# 2 2020-02-17  Afghanistan                     0.0              NaN
# 3 2020-02-18  Afghanistan                     0.0              NaN
# 4 2020-02-19  Afghanistan                     0.0              NaN
#
#    active_cases  cumulative_total_deaths  daily_new_deaths year_month
# 0           0.0                      0.0               NaN    2020-02
# 1           0.0                      0.0               NaN    2020-02
# 2           0.0                      0.0               NaN    2020-02
# 3           0.0                      0.0               NaN    2020-02
# 4           0.0                      0.0               NaN    2020-02

# %%
# Find the countries with the most cases
most_cases_df = (daily_covid_df.groupby('country')['cumulative_total_cases']
                               .max()
                               .reset_index()
                               .sort_values(by='cumulative_total_cases', ascending=False)
                )
most_cases_df.head(10)
# Out:
#          country  cumulative_total_cases
# 212          USA              84209473.0
# 94         India              43121599.0
# 26        Brazil              30682094.0
# 72        France              29160802.0
# 78       Germany              25774509.0
# 211           UK              22159805.0
# 165       Russia              18255337.0
# 189  South Korea              17756627.0
# 101        Italy              17030711.0
# 209       Turkey              15053168.0

# %%
# Create a list  and dataframe of Countries with the most cases
top_ten_countries = ['USA', 'India', 'Brazil', 'France', 'Germany', 'UK', 'Russia', 'South Korea', 'Italy', 'Turkey']
top_ten_df = daily_covid_df[daily_covid_df['country'].isin(top_ten_countries)]
top_ten_df
# Out:
#              date country  cumulative_total_cases  daily_new_cases  \
# 21320  2020-02-15  Brazil                     0.0              NaN
# 21321  2020-02-16  Brazil                     0.0              NaN
# 21322  2020-02-17  Brazil                     0.0              NaN
# 21323  2020-02-18  Brazil                     0.0              NaN
# 21324  2020-02-19  Brazil                     0.0              NaN
# ...           ...     ...                     ...              ...
# 177402 2022-05-10     USA              83895556.0          85415.0
# 177403 2022-05-11     USA              83994864.0          99308.0
# 177404 2022-05-12     USA              84093964.0          99100.0
# 177405 2022-05-13     USA              84182733.0          88769.0
# 177406 2022-05-14     USA              84209473.0          26740.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths year_month
# 21320            0.0                      0.0               NaN    2020-02
# ...

# %%
group_by_df = filtered_df.groupby(['year_month','country'])['active_cases'].mean().reset_index()
