# %%
# Import dependencies
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import linregress
from matplotlib import pyplot as plt
from pathlib import Path

# %%
# Read in CSV
datafile = Path("predicting_misuse_csv.csv")
original_df = pd.read_csv(datafile)
original_df.head()
# Out:
#    YEAR  AGECAT  SEX  MARRIED  EDUCAT  EMPLOY18  CTYMETRO  HEALTH  MENTHLTH  \
# 0    15       3    1        0       2         2         0       3         4
# 1    15       3    0        0       3         1         0       6         7
# 2    15       2    0        0       3         0         0       4         2
# 3    15       1    0        0       1         0         0       5         0
# 4    15       5    0        0       3         0         0       5         2
#
#    PRLMISEVR  ...  PRLANY  HEROINEVR  HEROINUSE  TRQLZRS  SEDATVS  COCAINE  \
# 0          1  ...      10          1          5        5        0        5
# 1          1  ...      10          1          5        5        0        4
# 2          1  ...       9          1          5        5        0        4
# 3          1  ...       9          1          5        5        0        3
# 4          1  ...       9          1          5        5        3        2
#
#    AMPHETMN  HALUCNG  TRTMENT  MHTRTMT
# ...

# %%
# Add a column for sum
original_df["Drug Use Total"] = ""
original_df.head()
# Out:
#    YEAR  AGECAT  SEX  MARRIED  EDUCAT  EMPLOY18  CTYMETRO  HEALTH  MENTHLTH  \
# 0    15       3    1        0       2         2         0       3         4
# 1    15       3    0        0       3         1         0       6         7
# 2    15       2    0        0       3         0         0       4         2
# 3    15       1    0        0       1         0         0       5         0
# 4    15       5    0        0       3         0         0       5         2
#
#    PRLMISEVR  ...  HEROINEVR  HEROINUSE  TRQLZRS  SEDATVS  COCAINE  AMPHETMN  \
# 0          1  ...          1          5        5        0        5         2
# 1          1  ...          1          5        5        0        4         3
# 2          1  ...          1          5        5        0        4         2
# 3          1  ...          1          5        5        0        3         2
# 4          1  ...          1          5        5        3        2         2
#
#    HALUCNG  TRTMENT  MHTRTMT  Drug Use Total
# ...

# %%
# Sum illict drug use (without Rx misuse) and add to empty column (function from chatGPT)
selected_columns = ["HEROINUSE", "TRQLZRS","SEDATVS","COCAINE","AMPHETMN","HALUCNG"]
for index, row in original_df.iterrows():
    original_df.loc[index, 'Drug Use Total'] = row[selected_columns].sum()

original_df.head()
# Out:
#    YEAR  AGECAT  SEX  MARRIED  EDUCAT  EMPLOY18  CTYMETRO  HEALTH  MENTHLTH  \
# 0    15       3    1        0       2         2         0       3         4
# 1    15       3    0        0       3         1         0       6         7
# 2    15       2    0        0       3         0         0       4         2
# 3    15       1    0        0       1         0         0       5         0
# 4    15       5    0        0       3         0         0       5         2
#
#    PRLMISEVR  ...  HEROINEVR  HEROINUSE  TRQLZRS  SEDATVS  COCAINE  AMPHETMN  \
# 0          1  ...          1          5        5        0        5         2
# 1          1  ...          1          5        5        0        4         3
# 2          1  ...          1          5        5        0        4         2
# 3          1  ...          1          5        5        0        3         2
# 4          1  ...          1          5        5        3        2         2
#
#    HALUCNG  TRTMENT  MHTRTMT  Drug Use Total
# ...

# %%
# Create a correlation matrix to determine which variables are more highly correlated with illicit drug use  (https://www.geeksforgeeks.org/create-a-correlation-matrix-using-python/)
matrix = original_df.corr()
plt.imshow(matrix, cmap='Blues')
plt.colorbar()
variables = []
for i in matrix.columns:
  variables.append(i)
plt.xticks(range(len(matrix)), variables, rotation="vertical", ha='center')
plt.yticks(range(len(matrix)), variables)
plt.show()
print(matrix)
# Out:
#                     YEAR    AGECAT       SEX   MARRIED    EDUCAT  EMPLOY18  \
# YEAR            1.000000  0.001040 -0.010292  0.524612  0.008496  0.005723
# AGECAT          0.001040  1.000000  0.038612  0.455686  0.614084  0.363161
# SEX            -0.010292  0.038612  1.000000  0.023999  0.065258 -0.066128
# MARRIED         0.524612  0.455686  0.023999  1.000000  0.345692  0.227538
# EDUCAT          0.008496  0.614084  0.065258  0.345692  1.000000  0.563160
# EMPLOY18        0.005723  0.363161 -0.066128  0.227538  0.563160  1.000000
# CTYMETRO        0.745119 -0.005261 -0.009375  0.505953  0.026049  0.010670
# HEALTH         -0.001732  0.241114  0.041776  0.071457  0.026110 -0.056569
# MENTHLTH        0.011653  0.135550  0.113684  0.047309  0.262511  0.126376
# PRLMISEVR      -0.007442  0.026110 -0.023388  0.003617  0.084066  0.079131
# PRLMISAB       -0.013055 -0.009737 -0.020923 -0.021796  0.035535  0.036873
# ...

# %%
# Create new dataframe to compare drug use to education
# Rename columns
education_df = original_df [["YEAR", "EDUCAT", "HEROINUSE", "TRQLZRS", "SEDATVS", "COCAINE", "AMPHETMN", "HALUCNG", "Drug Use Total"]]
education_df = education_df.rename(columns={"YEAR": "Year", 
                                            "EDUCAT": "Education", 
                                            "HEROINUSE": "Heroin Use", 
                                            "TRQLZRS": "Tranquilizer Use", 
                                            "SEDATVS": "Sedative Use", 
                                            "COCAINE": "Cocaine Use", 
                                            "AMPHETMN": "Amphetamine Use", 
                                            "HALUCNG": "Hallucinogen Use"
                                           })
education_df.head()
# Out:
#    Year  Education  Heroin Use  Tranquilizer Use  Sedative Use  Cocaine Use  \
# 0    15          2           5                 5             0            5
# 1    15          3           5                 5             0            4
# 2    15          3           5                 5             0            4
# 3    15          1           5                 5             0            3
# 4    15          3           5                 5             3            2
#
#    Amphetamine Use  Hallucinogen Use Drug Use Total
# 0                2                 2             19
# 1                3                 5             22
# 2                2                 3             19
# 3                2                 2             17
# 4                2                 2             19

# %%
education_df['Drug Use Total'] = education_df['Drug Use Total'].astype(np.int64)
education_df.dtypes
# Out:
# Year                int64
# Education           int64
# Heroin Use          int64
# Tranquilizer Use    int64
# Sedative Use        int64
# Cocaine Use         int64
# Amphetamine Use     int64
# Hallucinogen Use    int64
# Drug Use Total      int64
# dtype: object

# %%
# Export the Education dataframe into a csv
education_df.to_csv("output_data/education.csv", index_label="City_ID")

# %%
x_values = education_df["Education"]
y_values = education_df["Drug Use Total"]
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(x_values.isnull().sum())
print(y_values.isnull().sum())
# Out:
# 0
# 0

# %%
# Define a function to create Linear Regression plots
def Lin_Reg_Plt(df, x, y):
    x_values = df[x]
    y_values = df[y]
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    rvalue = round(rvalue, 5)
    
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values, y_values, s=60, color='darkcyan', edgecolor='black')
    
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, xy=(0.5, 0.1), xycoords='axes fraction', fontsize=15,color="red", ha='center', va='bottom')

    plt.xlabel(x)
    plt.ylabel(y)
    print("The r-value is: " + str(rvalue))
    plt.show()

# %%
Lin_Reg_Plt(education_df ,"Education", "Drug Use Total")
# Out:
# The r-value is: 0.14934
